# %%
import pandas as pd

# %%
df = pd.read_csv('TotnghiepOK.csv');
df
# Out:
# C:\Users\Minh Chi\AppData\Local\Temp\ipykernel_16432\980758278.py:1: DtypeWarning: Columns (15) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('TotnghiepOK.csv');
#        Unnamed: 0    SoBD  Toan   Van       Anh    Ly   Hoa  Sinh    Su   Dia  \
# 0              18      19   6.6  7.50  5.000000  6.25  4.25  4.25  5.25  7.75
# 1             170     171   4.6  4.00  2.600000  2.25  3.00  2.25  2.75  4.50
# 2             178     179   5.0  5.25  3.200000  5.75  4.25  4.75  4.25  5.50
# 3             189     190   4.0  4.50  3.200000  2.75  4.25  5.50  3.00  5.25
# 4             194     195   3.8  5.75  2.800000  2.75  3.00  2.75  3.50  6.00
# ...           ...     ...   ...   ...       ...   ...   ...   ...   ...   ...
# 33864      743440  743441   5.6  2.75  3.933543  2.25  4.50  2.75  3.75  5.75
# 33865      743504  743505   3.8  5.50  3.933543  2.25  5.00  4.25  3.50  4.25
# ...

# %%
cut_lable = ['Yeu', 'Trung binh', 'Kha', 'Gioi']
cut_bin = [0, 4, 6.5, 7, 10]
df['col_Math'] = pd.cut(df['Toan'], bins=cut_bin, labels=cut_lable,  include_lowest=True )  # bao gồm 0 vào nhãn đầu)
df['col_Math']
# Out:
# 0               Kha
# 1        Trung binh
# 2        Trung binh
# 3               Yeu
# 4               Yeu
#             ...
# 33864    Trung binh
# 33865           Yeu
# 33866    Trung binh
# 33867           Yeu
# 33868           Yeu
# Name: col_Math, Length: 33869, dtype: category
# Categories (4, object): ['Yeu' < 'Trung binh' < 'Kha' < 'Gioi']

# %%
cut_lable = ['Trung binh', 'Kha', 'Gioi']
cut_bin = [0, 6.5, 8, 10]
df['col_Eng'] = pd.cut(df['Anh'], bins = cut_bin, labels= cut_lable)
df['col_Eng']
# Out:
# 0        Trung binh
# 1        Trung binh
# 2        Trung binh
# 3        Trung binh
# 4        Trung binh
#             ...
# 33864    Trung binh
# 33865    Trung binh
# 33866    Trung binh
# 33867    Trung binh
# 33868    Trung binh
# Name: col_Eng, Length: 33869, dtype: category
# Categories (3, object): ['Trung binh' < 'Kha' < 'Gioi']
