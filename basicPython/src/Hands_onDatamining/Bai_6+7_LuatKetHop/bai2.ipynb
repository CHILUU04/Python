# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv('D:\\learn_PyThon\\basicPython\\src\\Hands_onDatamining\\Bai_4+5_XuLyDuLieu\\105OK.csv')
df
# Out:
#     Access  CT du lieu  CT may tinh  CNXHKH  Chuyen de   CS du lieu  \
# 0     True        True         True    True        True        True
# 1     True        True         True    True        True        True
# 2     True        True         True    True        True        True
# 3     True        True         True    True        True        True
# 4     True        True         True    True        True        True
# ..     ...         ...          ...     ...         ...         ...
# 94   False        True         True    True        True        True
# 95   False        True         True    True        True        True
# 96   False        True         True    True        True        True
# 97   False        True         True    True        True        True
# 98   False       False        False   False       False       False
#
#     Cong nghe NET   CNphan mem  Dai so so hoc  DS tuyen tinh  ...  \
# 0            False        True           True           True  ...
# ...

# %%
# tìm tập xuất hiện thường xuyên

# frenquent_itemset = apriori(df, min_support=0.4, use_colnames=True, low_memory=True)
# frenquent_itemset
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[3], line 2
#       1 # tìm tập xuất hiện thường xuyên
# ----> 2 frenquent_itemset = apriori(df, min_support=0.4, use_colnames=True, low_memory=True)
#       3 frenquent_itemset
#
# File d:\learn_PyThon\.venv\Lib\site-packages\mlxtend\frequent_patterns\apriori.py:275, in apriori(df, min_support, use_colnames, max_len, verbose, low_memory)
#     271 combin = generate_new_combinations_low_memory(
#     272     itemset_dict[max_itemset], X, min_support, is_sparse
#     273 )
#     274 # slightly faster than creating an array from a list of tuples
# --> 275 combin = np.fromiter(combin, dtype=int)
#     276 combin = combin.reshape(-1, next_max_itemset + 1)
#     278 if combin.size == 0:
#
# MemoryError: cannot allocate array memory

# %%
# đối với fp-growth
from mlxtend.frequent_patterns import fpgrowth, association_rules
freq_itemsets = fpgrowth(df, min_support=0.4, use_colnames=True)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[4], line 3
#       1 # đối với fp-growth
#       2 from mlxtend.frequent_patterns import fpgrowth, association_rules
# ----> 3 freq_itemsets = fpgrowth(df, min_support=0.4, use_colnames=True)
#
# File d:\learn_PyThon\.venv\Lib\site-packages\mlxtend\frequent_patterns\fpgrowth.py:95, in fpgrowth(df, min_support, null_values, use_colnames, max_len, verbose)
#      92 minsup = math.ceil(min_support * len(df.index))  # min support as count
#      93 generator = fpg_step(tree, minsup, colname_map, max_len, verbose)
# ---> 95 return fpc.generate_itemsets(
#      96     generator, df, disabled, min_support, len(df.index), colname_map
#      97 )
#
# File d:\learn_PyThon\.venv\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:75, in generate_itemsets(generator, df, disabled, min_support, num_itemsets, colname_map)
# ...

# %%
rules = association_rules(freq_itemsets, metric= 'confident', min_threshold=0.6)
rules
