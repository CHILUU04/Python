# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
dataset = [['Milk', 'Onion', 'Apple', 'Kidney Beans', 'Eggs', 'Yogurt'],
            ['Banana', 'Onion', 'Apple', 'Kidney Beans', 'Eggs', 'Yogurt'],
            ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
            ['Milk', 'Ice cream', 'Corn', 'Kidney Beans', 'Yogurt'],
            ['Corn', 'Apple', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]
dataset
# Out:
# [['Milk', 'Onion', 'Apple', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Banana', 'Onion', 'Apple', 'Kidney Beans', 'Eggs', 'Yogurt'],
#  ['Milk', 'Apple', 'Kidney Beans', 'Eggs'],
#  ['Milk', 'Ice cream', 'Corn', 'Kidney Beans', 'Yogurt'],
#  ['Corn', 'Apple', 'Onion', 'Kidney Beans', 'Ice cream', 'Eggs']]

# %%
#Transaction Encoder
te = TransactionEncoder()
te_ary = te.fit(dataset).transform(dataset)
df = pd.DataFrame(te_ary, columns=te.columns_)

# %%
df
# Out:
#    Apple  Banana   Corn   Eggs  Ice cream  Kidney Beans   Milk  Onion  Yogurt
# 0   True   False  False   True      False          True   True   True    True
# 1   True    True  False   True      False          True  False   True    True
# 2   True   False  False   True      False          True   True  False   False
# 3  False   False   True  False       True          True   True  False    True
# 4   True   False   True   True       True          True  False   True   False

# %%
#Using Apriori to find frequent itemset
# tìm tập mục thường xuyên( mục tiêu để tìm tập hợp nào xuất hiện ít nhất trong 40% giao dịch )
frequent_itemsets = apriori(df, min_support=0.4, use_colnames=True)
frequent_itemsets
# Out:
#     support                                    itemsets
# 0       0.8                                     (Apple)
# 1       0.4                                      (Corn)
# 2       0.8                                      (Eggs)
# 3       0.4                                 (Ice cream)
# 4       1.0                              (Kidney Beans)
# 5       0.6                                      (Milk)
# 6       0.6                                     (Onion)
# 7       0.6                                    (Yogurt)
# 8       0.8                               (Eggs, Apple)
# 9       0.8                       (Kidney Beans, Apple)
# 10      0.4                               (Milk, Apple)
# 11      0.6                              (Onion, Apple)
# 12      0.4                             (Yogurt, Apple)
# 13      0.4                           (Ice cream, Corn)
# 14      0.4                        (Kidney Beans, Corn)
# 15      0.8                        (Kidney Beans, Eggs)
# ...

# %%
#Mining rules from frequent itemset 
# Sinh Luật Kết Hợp 
from mlxtend.frequent_patterns import association_rules
rules=association_rules(frequent_itemsets, metric="confidence", min_threshold=0.85)
# X ⇒ Y thỏa mãn độ tin cậy (confidence) ≥ 0.85, đồng thời support của X∪Y vẫn ≥ min_support bạn đã đặt trước đó.
rules
#conf(y|x) =
# Out:
# d:\learn_PyThon\.venv\Lib\site-packages\mlxtend\frequent_patterns\association_rules.py:186: RuntimeWarning: invalid value encountered in divide
#   cert_metric = np.where(certainty_denom == 0, 0, certainty_num / certainty_denom)
#                       antecedents                   consequents  \
# 0                          (Eggs)                       (Apple)
# 1                         (Apple)                        (Eggs)
# 2                         (Apple)                (Kidney Beans)
# 3                         (Onion)                       (Apple)
# 4                     (Ice cream)                        (Corn)
# ..                            ...                           ...
# 87          (Apple, Yogurt, Eggs)         (Kidney Beans, Onion)
# 88  (Kidney Beans, Yogurt, Apple)                 (Onion, Eggs)
# 89                (Yogurt, Onion)   (Apple, Kidney Beans, Eggs)
# 90                 (Yogurt, Eggs)  (Kidney Beans, Onion, Apple)
# ...

# %%
#Filtering the rules
rules[ (rules['lift'] >= 1) & #Lift ≥ 1 nghĩa là X và Y có xu hướng xuất hiện cùng nhau và Confidence = P(Y|X): nếu X xảy ra, xác suất có Y ít nhất 40%.
       (rules['confidence'] >= 0.4) ].sort_values(['confidence'], ascending =False) # acending: sắp xếp thoe thứ tự giảm dần
# Out:
#                     antecedents            consequents  antecedent support  \
# 0                        (Eggs)                (Apple)                 0.8
# 1                       (Apple)                 (Eggs)                 0.8
# 2                       (Apple)         (Kidney Beans)                 0.8
# 5                       (Onion)                (Apple)                 0.6
# 7                        (Corn)            (Ice cream)                 0.4
# ..                          ...                    ...                 ...
# 68         (Eggs, Kidney Beans)         (Apple, Onion)                 0.8
# 67                (Eggs, Apple)  (Kidney Beans, Onion)                 0.8
# 63  (Eggs, Apple, Kidney Beans)                (Onion)                 0.8
# 51                       (Eggs)  (Kidney Beans, Onion)                 0.8
# 48         (Eggs, Kidney Beans)                (Onion)                 0.8
#
# ...

# %%
rules[ (rules['support'] >= 0.8) ]
# Out:
#               antecedents            consequents  antecedent support  \
# 0                  (Eggs)                (Apple)                 0.8
# 1                 (Apple)                 (Eggs)                 0.8
# 2                 (Apple)         (Kidney Beans)                 0.8
# 3          (Kidney Beans)                (Apple)                 1.0
# 9                  (Eggs)         (Kidney Beans)                 0.8
# 10         (Kidney Beans)                 (Eggs)                 1.0
# 17          (Eggs, Apple)         (Kidney Beans)                 0.8
# 18   (Eggs, Kidney Beans)                (Apple)                 0.8
# 19  (Apple, Kidney Beans)                 (Eggs)                 0.8
# 20                 (Eggs)  (Apple, Kidney Beans)                 0.8
# 21                (Apple)   (Eggs, Kidney Beans)                 0.8
# 22         (Kidney Beans)          (Eggs, Apple)                 1.0
#
# ...

# %%
rules[rules['antecedents']==frozenset({'Apple'})]
# Out:
#    antecedents           consequents  antecedent support  consequent support  \
# 1      (Apple)                (Eggs)                 0.8                 0.8
# 2      (Apple)        (Kidney Beans)                 0.8                 1.0
# 17     (Apple)  (Kidney Beans, Eggs)                 0.8                 0.8
#
#     support  confidence  lift  representativity  leverage  conviction  \
# 1       0.8         1.0  1.25               1.0      0.16         inf
# 2       0.8         1.0  1.00               1.0      0.00         inf
# 17      0.8         1.0  1.25               1.0      0.16         inf
#
#     zhangs_metric  jaccard  certainty  kulczynski
# 1             1.0      1.0        1.0         1.0
# 2             0.0      0.8        0.0         0.9
# 17            1.0      1.0        1.0         1.0
